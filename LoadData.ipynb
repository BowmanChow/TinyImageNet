# %%
import moxing as mox
mox.file.copy_parallel("obs://qwq/TinyImageNet.zip","/home/ma-user/work/TinyImageNet.zip")
# Out:
# INFO:root:Using MoXing-v1.17.3-
# INFO:root:Using OBS-Python-SDK-3.20.7

# %%
import zipfile


zFile = zipfile.ZipFile("/home/ma-user/work/TinyImageNet.zip", "r")
    #ZipFile.namelist(): 获取ZIP文档内所有文件的名称列表
for file in zFile.namelist():
    zFile.extract(file,"/home/ma-user/work")
zFile.close();
